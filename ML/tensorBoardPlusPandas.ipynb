# %%
# pip install tensorboard pandas matplotlibd
# https://stackoverflow.com/a/52095336/7517624 
from matplotlib import pyplot as plt 
import pandas as pd
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

tfevents_filename =

# %%
ev_accu = EventAccumulator(tfevents_filename).Reload()  
df = pd.DataFrame({i: {ev.step: ev.value for ev in ev_accu.Scalars(i)} for i in ev_accu.Tags()['scalars'] })
df
# Out:
#        train/loss  train/learning_rate  train/epoch  eval/loss  eval/accuracy  \
# 500        0.1409             0.000497     0.190000   0.106272       0.957695
# 1000       0.0938             0.000494     0.380000   0.076400       0.972831
# 1500       0.0792             0.000491     0.560000   0.066503       0.979223
# 2000       0.0764             0.000487     0.750000   0.059951       0.979694
# 2500       0.0683             0.000484     0.940000   0.050158       0.982702
# ...           ...                  ...          ...        ...            ...
# 78000      0.0034             0.000011    29.320000   0.039065       0.993983
# 78500      0.0056             0.000008    29.510000   0.038167       0.993983
# 79000      0.0056             0.000005    29.700001   0.038234       0.994077
# 79500      0.0036             0.000002    29.889999   0.038133       0.994171
# 79800         NaN                  NaN    30.000000        NaN            NaN
#
# ...

# %%
ax = df[['eval/loss','eval/accuracy','eval/f1','eval/roc_auc']].plot.line()
